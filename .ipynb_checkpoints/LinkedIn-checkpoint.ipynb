# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_boxoffice(path):
    # read safely with latin1 encoding
    df = pd.read_csv(path, encoding='latin1', low_memory=False)
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
    
    # rename key fields
    rename_map = {
        'release_group':'title',
        'worldwide':'revenue_worldwide',
        'domestic':'revenue_domestic',
        'foreign':'revenue_foreign',
        'domestic_percent':'domestic_pct',
        'foreign_percent':'foreign_pct',
        'year':'release_year'
    }
    df = df.rename(columns=rename_map)

    # remove commas and convert numeric columns
    for col in ['revenue_worldwide','revenue_domestic','revenue_foreign']:
        df[col] = (
            df[col].astype(str)
                    .str.replace('[^0-9]', '', regex=True)
                    .replace('', np.nan)
                    .astype(float)
        )
    
    # clean percentages
    for col in ['domestic_pct','foreign_pct']:
        df[col] = (
            df[col].astype(str)
                    .str.replace('%','')
                    .replace('', np.nan)
                    .astype(float)
        )

    # clean titles
    df['title'] = df['title'].astype(str).str.strip()

    # fix year type
    df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce').astype('Int64')

    # remove empty rows (no revenue at all)
    df = df[(df['revenue_worldwide']>0) | (df['revenue_domestic']>0)]
    
    return df

# %%
import re

def parse_money_series(s):
    # strip everything except digits
    s = (s.astype(str)
          .str.replace(r'[^0-9]', '', regex=True)
          .replace({'': np.nan}))
    return s.astype(float)

def parse_percent_series(s, lt_policy="mid"):  
    """
    Parse percentage-like strings to float (0-100).
    Handles values like '39.40%', '100', '<0.1', '-', '—', ''.
    
    lt_policy:
      - 'mid' -> '<0.1' becomes 0.05  (midpoint; neutral)
      - 'ceil' -> '<0.1' becomes 0.1  (conservative upper bound)
      - 'zero' -> '<0.1' becomes 0.0  (lower bound)
      - 'nan' -> '<0.1' becomes NaN   (treat as unknown)
    """
    s = s.astype(str).str.strip()

    # normalize dashes and empties to NaN
    s = s.replace({'' : np.nan, '-' : np.nan, '—' : np.nan, '–' : np.nan})

    # remove trailing % and thousands commas/spaces
    s = s.str.replace('%', '', regex=False).str.replace(',', '', regex=False)

    # handle "<x" cases first
    mask_lt = s.str.startswith('<', na=False)
    if mask_lt.any():
        # extract the number after '<'
        nums = s.where(mask_lt).str.extract(r'<\s*([0-9]*\.?[0-9]+)', expand=False)
        if lt_policy == "mid":
            vals = pd.to_numeric(nums, errors='coerce') / 2.0
        elif lt_policy == "ceil":
            vals = pd.to_numeric(nums, errors='coerce')
        elif lt_policy == "zero":
            vals = 0.0
        else:  # 'nan'
            vals = np.nan
        s = s.mask(mask_lt, vals)

    # strip any stray non-numeric (just in case)
    s = s.str.replace(r'[^0-9\.]', '', regex=True).replace({'': np.nan})

    return pd.to_numeric(s, errors='coerce')

def load_boxoffice(path, lt_policy="mid"):
    df = pd.read_csv(path, encoding='latin1', low_memory=False)
    df.columns = (df.columns.str.strip()
                              .str.lower()
                              .str.replace(' ', '_'))

    rename_map = {
        'release_group':'title',
        'worldwide':'revenue_worldwide',
        'domestic':'revenue_domestic',
        'foreign':'revenue_foreign',
        'domestic_percent':'domestic_pct',
        'foreign_percent':'foreign_pct',
        'year':'release_year'
    }
    df = df.rename(columns=rename_map)

    # money columns
    for col in ['revenue_worldwide','revenue_domestic','revenue_foreign']:
        df[col] = parse_money_series(df[col])

    # percent columns (remain 0–100 floats)
    for col in ['domestic_pct','foreign_pct']:
        if col in df.columns:
            df[col] = parse_percent_series(df[col], lt_policy=lt_policy)

    # title/year cleanup
    df['title'] = df['title'].astype(str).str.strip()
    df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce').astype('Int64')

    # drop rows with zero across the board (likely junk)
    df = df[(df['revenue_worldwide'].fillna(0) > 0) | (df['revenue_domestic'].fillna(0) > 0)]

    return df

# %%
df_00s = load_boxoffice('D:/LinkedIn Features/Movie project/2000-2009 Movies Box Office Collection.csv',
                        lt_policy="mid")   # or "ceil"/"zero"/"nan"

# %%
df_00s.head()
# Out:
#    unnamed:_0                   title  revenue_worldwide  revenue_domestic  \
# 0           0  Mission: Impossible II        546388108.0       215409889.0
# 1           1               Gladiator        460583960.0       187705427.0
# 2           2               Cast Away        429632142.0       233632142.0
# 3           3         What Women Want        374111707.0       182811707.0
# 4           4                Dinosaur        349822765.0       137748063.0
#
#    domestic_pct  revenue_foreign  foreign_pct  release_year
# 0          39.4      330978219.0         60.6          2000
# 1          40.8      272878533.0         59.2          2000
# 2          54.4      196000000.0         45.6          2000
# 3          48.9      191300000.0         51.1          2000
# 4          39.4      212074702.0         60.6          2000

# %%
df_1020s = load_boxoffice('D:/LinkedIn Features/Movie project/2010-2024 Movies Box Office Collection.csv',
                        lt_policy="mid")
df_1020s.head()
# Out:
#    rank                                         title  revenue_worldwide  \
# 0     0                                   Toy Story 3       1.066970e+09
# 1     1                           Alice in Wonderland       1.025467e+09
# 2     2  Harry Potter and the Deathly Hallows: Part 1       9.602833e+08
# 3     3                                     Inception       8.282587e+08
# 4     4                           Shrek Forever After       7.526009e+08
#
#    revenue_domestic  domestic_pct  revenue_foreign  foreign_pct  release_year
# 0       415004880.0          38.9      651964823.0         61.1          2010
# 1       334191110.0          32.6      691276000.0         67.4          2010
# 2       295983305.0          30.8      664300000.0         69.2          2010
# 3       292576195.0          35.3      535682500.0         64.7          2010
# 4       238736787.0          31.7      513864080.0         68.3          2010

# %%
df_2024 = load_boxoffice('D:/LinkedIn Features/Movie project/2024 Movies Box Office Collection.csv',
                        lt_policy="mid")
df_2024.head()
# Out:
#    unnamed:_0                            title  revenue_worldwide  \
# 0           0                     Inside Out 2       1.595984e+09
# 1           1             Deadpool & Wolverine       1.043180e+09
# 2           2                  Despicable Me 4       8.085376e+08
# 3           3                   Dune: Part Two       7.118444e+08
# 4           4  Godzilla x Kong: The New Empire       5.676500e+08
#
#    revenue_domestic  domestic_pct  revenue_foreign  foreign_pct  release_year
# 0       637852840.0          40.0      958130854.0         60.0          2024
# 1       506937007.0          48.6      536243178.0         51.4          2024
# 2       332583715.0          41.1      475953856.0         58.9          2024
# 3       282144358.0          39.6      429700000.0         60.4          2024
# 4       196350016.0          34.6      371300000.0         65.4          2024

# %%
#df_00s = load_boxoffice(r'D:/LinkedIn Features/Movie project/2000-2009 Movies Box Ofice Collection.csv')
#df_10s = load_boxoffice(r'D:/LinkedIn Features/Movie project/2010-2024 Movies Box Ofice Collection.csv')
df_24  = load_boxoffice(r'D:/LinkedIn Features/Movie project/2024 Movies Box Ofice Collection.csv')

# %%
df_00s = load_boxoffice(r'D:/LinkedIn Features/Movie project/2000-2009 Movies Box Office Collection.csv')
df_10s = load_boxoffice(r'D:/LinkedIn Features/Movie project/2010-2024 Movies Box Office Collection.csv')
df_24  = load_boxoffice(r'D:/LinkedIn Features/Movie project/2024 Movies Box Office Collection.csv')

# unify
df = pd.concat([df_00s, df_10s, df_24], ignore_index=True)

# simple key to dedupe if any overlap
df['title_key'] = (df['title'].astype(str)
                   .str.strip()
                   .str.replace(r'\s+', ' ', regex=True)
                   .str.lower())
df = df.drop_duplicates(subset=['title_key','release_year']).reset_index(drop=True)

# optional: sanity check % sums (flag rows that are far from 100)
pct_check = (df[['domestic_pct','foreign_pct']]
             .dropna()
             .assign(total=lambda x: x['domestic_pct'] + x['foreign_pct']))
bad_pct = df.loc[(df['domestic_pct'].notna()) & (df['foreign_pct'].notna())
                 & (np.abs(pct_check['total'] - 100) > 1.5)]
# If you want to auto-normalize small drift:
mask = (df['domestic_pct'].notna()) & (df['foreign_pct'].notna())
total = (df.loc[mask, 'domestic_pct'] + df.loc[mask, 'foreign_pct']).replace(0, np.nan)
df.loc[mask, 'domestic_pct'] = df.loc[mask, 'domestic_pct'] / total * 100
df.loc[mask, 'foreign_pct']  = df.loc[mask, 'foreign_pct']  / total * 100
df.drop(columns='unnamed:_0', inplace=True)
df.to_csv('boxoffice_clean_2000_2024.csv', index=False)

# %%
def event_period(y):
    if y <= 2001: return "Pre-9/11"
    elif 2002 <= y <= 2003: return "Post-9/11"
    elif 2007 <= y <= 2009: return "Financial Crisis"
    elif 2020 <= y <= 2021: return "Covid-19"
    elif y >= 2022: return "Recovery"
    else: return "Stable Growth"

df['event_period'] = df['release_year'].apply(event_period)
df.head()
# Out:
#                     title  revenue_worldwide  revenue_domestic  domestic_pct  \
# 0  Mission: Impossible II        546388108.0       215409889.0          39.4
# 1               Gladiator        460583960.0       187705427.0          40.8
# 2               Cast Away        429632142.0       233632142.0          54.4
# 3         What Women Want        374111707.0       182811707.0          48.9
# 4                Dinosaur        349822765.0       137748063.0          39.4
#
#    revenue_foreign  foreign_pct  release_year  rank               title_key  \
# 0      330978219.0         60.6          2000   NaN  mission: impossible ii
# 1      272878533.0         59.2          2000   NaN               gladiator
# 2      196000000.0         45.6          2000   NaN               cast away
# 3      191300000.0         51.1          2000   NaN         what women want
# 4      212074702.0         60.6          2000   NaN                dinosaur
#
#   event_period
# 0     Pre-9/11
# 1     Pre-9/11
# 2     Pre-9/11
# 3     Pre-9/11
# 4     Pre-9/11

# %%
df.columns
# Out:
# Index(['title', 'revenue_worldwide', 'revenue_domestic', 'domestic_pct',
#        'revenue_foreign', 'foreign_pct', 'release_year', 'rank', 'title_key',
#        'event_period'],
#       dtype='object')

# %%
df.head()
# Out:
#                     title  revenue_worldwide  revenue_domestic  domestic_pct  \
# 0  Mission: Impossible II        546388108.0       215409889.0          39.4
# 1               Gladiator        460583960.0       187705427.0          40.8
# 2               Cast Away        429632142.0       233632142.0          54.4
# 3         What Women Want        374111707.0       182811707.0          48.9
# 4                Dinosaur        349822765.0       137748063.0          39.4
#
#    revenue_foreign  foreign_pct  release_year  rank               title_key  \
# 0      330978219.0         60.6          2000   NaN  mission: impossible ii
# 1      272878533.0         59.2          2000   NaN               gladiator
# 2      196000000.0         45.6          2000   NaN               cast away
# 3      191300000.0         51.1          2000   NaN         what women want
# 4      212074702.0         60.6          2000   NaN                dinosaur
#
#   event_period
# 0     Pre-9/11
# 1     Pre-9/11
# 2     Pre-9/11
# 3     Pre-9/11
# 4     Pre-9/11

# %%
df.sample(10)
# Out:
#                     title  revenue_worldwide  revenue_domestic  domestic_pct  \
# 3198    Serial Teachers 2         25364150.0               0.0           0.0
# 4563        Table for Six         10138355.0               0.0           0.0
# 3915         Breakthrough         50444358.0        40713082.0          80.7
# 4502          Turning Red         21521622.0         1399001.0           6.5
# 131   I Dreamed of Africa         14400327.0         6651522.0          46.2
# 103           Boiler Room         28780255.0        16970581.0          59.0
# 3908         The Big Shot         56040681.0               0.0           0.0
# 1804                 2012        769679473.0       166112167.0          21.6
# 3451       Daddy's Home 2        180613180.0       104029443.0          57.6
# 2863          The Nut Job        120885527.0        64251541.0          53.2
#
#       revenue_foreign  foreign_pct  release_year   rank            title_key  \
# 3198       25364150.0        100.0          2015  198.0    serial teachers 2
# 4563       10138355.0        100.0          2022  164.0        table for six
# 3915        9731276.0         19.3          2019  115.0         breakthrough
# 4502       20122621.0         93.5          2022  102.0          turning red
# 131         7748805.0         53.8          2000    NaN  i dreamed of africa
# 103        11809674.0         41.0          2000    NaN          boiler room
# 3908       56040681.0        100.0          2019  108.0         the big shot
# 1804      603567306.0         78.4          2009    NaN                 2012
# 3451       76583737.0         42.4          2017   51.0       daddy's home 2
# 2863       56633986.0         46.8          2014   63.0          the nut job
#
#           event_period
# 3198     Stable Growth
# 4563          Recovery
# 3915     Stable Growth
# 4502          Recovery
# 131           Pre-9/11
# 103           Pre-9/11
# 3908     Stable Growth
# 1804  Financial Crisis
# 3451     Stable Growth
# 2863     Stable Growth

# %%
df['release_year'].sort_values().unique()
# Out:
# <IntegerArray>
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#  2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]
# Length: 25, dtype: Int64

# %%
year_rev = (df.groupby('release_year', as_index=False)['revenue_worldwide'].sum())


plt.figure(figsize=(11,6))
sns.lineplot(data=year_rev, x='release_year', y='revenue_worldwide', marker='o')
plt.title('Global Box Office Revenue (2000–2024)')
plt.xlabel('Year'); plt.ylabel('Worldwide Revenue')

# shade events
plt.axvspan(2001, 2003, color='grey', alpha=0.15, label='Post-9/11')
plt.axvspan(2007, 2009, color='orange', alpha=0.10, label='Financial Crisis')
plt.axvspan(2020, 2021, color='red',   alpha=0.08, label='Covid-19')
plt.legend()
plt.tight_layout()
#plt.show()
plt.savefig('globalboxofficerevenue.png', dpi=200, bbox_inches='tight')

# %%
titles_per_year = df.groupby('release_year')['title'].nunique().reset_index(name='n_titles')
avg_rev = year_rev.merge(titles_per_year, on='release_year', how='left')
avg_rev['revenue_per_film'] = avg_rev['revenue_worldwide'] / avg_rev['n_titles']

plt.figure(figsize=(11,6))
sns.lineplot(data=avg_rev, x='release_year', y='revenue_per_film', marker='o')
plt.title('Average Worldwide Revenue per Film (2000–2024)')
plt.xlabel('Year'); plt.ylabel('Revenue per Film')
plt.axvspan(2020, 2021, color='red', alpha=0.08)
plt.tight_layout()
#plt.show()
plt.savefig('avgworldwiderevenue.png', dpi=200, bbox_inches='tight')

# %%
year_parts = (df.groupby('release_year', as_index=False)
                .agg(domestic=('revenue_domestic','sum'),
                     foreign=('revenue_foreign','sum')))
year_parts['total'] = year_parts['domestic'] + year_parts['foreign']
year_parts[['domestic','foreign']] = year_parts[['domestic','foreign']].div(year_parts['total'], axis=0)*100

plt.figure(figsize=(11,6))
plt.stackplot(year_parts['release_year'],
              year_parts['domestic'], year_parts['foreign'],
              labels=['Domestic %','Foreign %'])
plt.title('Domestic vs Foreign Share of Worldwide Revenue')
plt.xlabel('Year'); plt.ylabel('Share (%)')
plt.legend(loc='upper right')
plt.tight_layout()
#plt.show()
plt.savefig('domvsforrevenue.png', dpi=200, bbox_inches='tight')

# %%
df[df['title'].str.contains('Avengers')][['title','revenue_worldwide', 'revenue_domestic','revenue_foreign','release_year']]
# Out:
#                         title  revenue_worldwide  revenue_domestic  \
# 2400             The Avengers       1.518813e+09       623357910.0
# 3003  Avengers: Age of Ultron       1.402806e+09       459005868.0
# 3600   Avengers: Infinity War       2.048360e+09       678815482.0
# 3800        Avengers: Endgame       2.799439e+09       858373000.0
#
#       revenue_foreign  release_year
# 2400     8.954551e+08          2012
# 3003     9.438000e+08          2015
# 3600     1.369544e+09          2018
# 3800     1.941066e+09          2019

# %%
df.columns
# Out:
# Index(['title', 'revenue_worldwide', 'revenue_domestic', 'domestic_pct',
#        'revenue_foreign', 'foreign_pct', 'release_year', 'rank', 'title_key',
#        'event_period'],
#       dtype='object')

# %%
top_100 = df[['title','revenue_worldwide', 'revenue_domestic','revenue_foreign','release_year']].sort_values(by=['revenue_worldwide','release_year'], 
                                                                                                   ascending= False).head(100)


top_100['title'].unique()
# Out:
# array(['Avengers: Endgame', 'Avatar', 'Avatar: The Way of Water',
#        'Star Wars: Episode VII 0 The Force Awakens',
#        'Avengers: Infinity War', 'Spider0Man: No Way Home',
#        'Jurassic World', 'The Lion King', 'Inside Out 2', 'The Avengers',
#        'Furious 7', 'Top Gun: Maverick', 'Frozen II', 'Barbie',
#        'Avengers: Age of Ultron', 'The Super Mario Bros. Movie',
#        'Black Panther', 'Harry Potter and the Deathly Hallows: Part 2',
#        'Star Wars: Episode VIII 0 The Last Jedi',
#        'Jurassic World: Fallen Kingdom', 'Frozen', 'Beauty and the Beast',
#        'Incredibles 2', 'The Fate of the Furious', 'Iron Man 3',
#        'Minions', 'Captain America: Civil War', 'Aquaman',
#        'The Lord of the Rings: The Return of the King',
#        'Spider0Man: Far from Home', 'Captain Marvel',
#        'Transformers: Dark of the Moon', 'Skyfall',
#        'Transformers: Age of Extinction', 'The Dark Knight Rises',
#        'Joker', 'Star Wars: Episode IX 0 The Rise of Skywalker',
#        'Toy Story 4', 'Toy Story 3',
#        "Pirates of the Caribbean: Dead Man's Chest",
#        'Rogue One: A Star Wars Story', 'Aladdin',
#        'Pirates of the Caribbean: On Stranger Tides',
#        'Deadpool & Wolverine', 'Despicable Me 3', 'Finding Dory',
#        'Alice in Wonderland', 'Zootopia',
#        'The Hobbit: An Unexpected Journey', 'The Dark Knight',
#        'Jurassic World Dominion', 'Oppenheimer',
#        "Harry Potter and the Sorcerer's Stone", 'Despicable Me 2',
#        'The Jungle Book', 'Jumanji: Welcome to the Jungle',
#        "Pirates of the Caribbean: At World's End",
#        'Harry Potter and the Deathly Hallows: Part 1',
#        'The Hobbit: The Desolation of Smaug',
#        'The Hobbit: The Battle of the Five Armies',
#        'Doctor Strange in the Multiverse of Madness',
#        'Harry Potter and the Order of the Phoenix',
#        'Minions: The Rise of Gru',
#        'Harry Potter and the Half0Blood Prince', 'Shrek 2',
#        'The Lord of the Rings: The Two Towers', 'Bohemian Rhapsody',
#        'The Battle at Lake Changjin',
#        'Harry Potter and the Goblet of Fire', 'Spider0Man 3',
#        'Ice Age: Dawn of the Dinosaurs', 'Spectre',
#        'Spider0Man: Homecoming',
#        'Harry Potter and the Chamber of Secrets',
#        'Ice Age: Continental Drift', 'The Secret Life of Pets',
#        'Batman v Superman: Dawn of Justice', 'Finding Nemo',
#        'Wolf Warrior 2',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'Star Wars: Episode III 0 Revenge of the Sith',
#        'The Hunger Games: Catching Fire',
#        'Guardians of the Galaxy Vol. 2', 'Black Panther: Wakanda Forever',
#        'Inside Out', 'Venom', 'Thor: Ragnarok',
#        'Guardians of the Galaxy Vol. 3',
#        'Transformers: Revenge of the Fallen',
#        'The Twilight Saga: Breaking Dawn 0 Part 2', 'Inception',
#        'Wonder Woman', 'Hi, Mom', 'Spider0Man',
#        'Fantastic Beasts and Where to Find Them', 'Coco',
#        'Shrek the Third', 'Despicable Me 4', 'Jumanji: The Next Level',
#        'Harry Potter and the Prisoner of Azkaban'], dtype=object)

# %%
top_100.to_csv('top_100_highest_rev.csv', index=False)
top_100.sample(50)
# Out:
#                                              title  revenue_worldwide  \
# 2202   Pirates of the Caribbean: On Stranger Tides       1.045714e+09
# 3002                                     Furious 7       1.515048e+09
# 2400                                  The Avengers       1.518813e+09
# 2801     The Hobbit: The Battle of the Five Armies       9.560198e+08
# 4202                                       Hi, Mom       8.220098e+08
# 2003                                     Inception       8.282587e+08
# 2404                    Ice Age: Continental Drift       8.772448e+08
# 400          The Lord of the Rings: The Two Towers       9.230152e+08
# 1200    Pirates of the Caribbean: Dead Man's Chest       1.066180e+09
# 2405     The Twilight Saga: Breaking Dawn 0 Part 2       8.297468e+08
# 3807                                   Toy Story 4       1.073395e+09
# 3004                                       Minions       1.159398e+09
# 801       Harry Potter and the Prisoner of Azkaban       7.956341e+08
# 3207       Fantastic Beasts and Where to Find Them       8.160376e+08
# 4200                       Spider0Man: No Way Home       1.912234e+09
# 3601                                 Black Panther       1.346913e+09
# 4402                       Jurassic World Dominion       1.001978e+09
# 3802                                     Frozen II       1.450027e+09
# 3600                        Avengers: Infinity War       2.048360e+09
# 4403   Doctor Strange in the Multiverse of Madness       9.557758e+08
# 3001                                Jurassic World       1.670401e+09
# 3003                       Avengers: Age of Ultron       1.402806e+09
# 3606                                         Venom       8.560852e+08
# 3602                Jurassic World: Fallen Kingdom       1.308468e+09
# 3404                Jumanji: Welcome to the Jungle       9.620775e+08
# 1402                                  Spider0Man 3       8.949834e+08
# 3405                        Spider0Man: Homecoming       8.801669e+08
# 2000                                   Toy Story 3       1.066970e+09
# 3805                                         Joker       1.078751e+09
# 2001                           Alice in Wonderland       1.025467e+09
# 4401                             Top Gun: Maverick       1.495696e+09
# 3801                                 The Lion King       1.656943e+09
# 3604                                       Aquaman       1.151962e+09
# 4404                      Minions: The Rise of Gru       9.402038e+08
# 3202                                  Finding Dory       1.028571e+09
# 4599                                        Barbie       1.445638e+09
# 1400      Pirates of the Caribbean: At World's End       9.609965e+08
# 4800                          Deadpool & Wolverine       1.043180e+09
# 3406                                Wolf Warrior 2       8.703254e+08
# 800                                        Shrek 2       9.289660e+08
# 2403             The Hobbit: An Unexpected Journey       1.017004e+09
# 1800                                        Avatar       2.743578e+09
# 1600                               The Dark Knight       1.003845e+09
# 2603           The Hobbit: The Desolation of Smaug       9.583669e+08
# 1001  Star Wars: Episode III 0 Revenge of the Sith       8.683525e+08
# 3403                               Despicable Me 3       1.034799e+09
# 3408                                Thor: Ragnarok       8.539771e+08
# 2401                                       Skyfall       1.108561e+09
# 2201                Transformers: Dark of the Moon       1.123794e+09
# 3804                                Captain Marvel       1.128275e+09
#
#       revenue_domestic  revenue_foreign  release_year
# 2202       241071802.0     8.046420e+08          2011
# 3002       353007020.0     1.162041e+09          2015
# 2400       623357910.0     8.954551e+08          2012
# 2801       255119788.0     7.009000e+08          2014
# 4202               0.0     8.220098e+08          2021
# 2003       292576195.0     5.356825e+08          2010
# 2404       161321843.0     7.159229e+08          2012
# 400        339789881.0     5.832254e+08          2002
# 1200       423315812.0     6.428639e+08          2006
# 2405       292324737.0     5.374221e+08          2012
# 3807       434038008.0     6.393566e+08          2019
# 3004       336045770.0     8.233526e+08          2015
# 801        249541069.0     5.460930e+08          2004
# 3207       234037575.0     5.820000e+08          2016
# 4200       804793477.0     1.107440e+09          2021
# 3601       700059566.0     6.468536e+08          2018
# 4402       376851080.0     6.251270e+08          2022
# 3802       477373578.0     9.726534e+08          2019
# 3600       678815482.0     1.369544e+09          2018
# 4403       411331607.0     5.444442e+08          2022
# 3001       652270625.0     1.018130e+09          2015
# 3003       459005868.0     9.438000e+08          2015
# 3606       213515506.0     6.425696e+08          2018
# 3602       417719760.0     8.907482e+08          2018
# 3404       404515480.0     5.575621e+08          2017
# 1402       336530303.0     5.584531e+08          2007
# 3405       334201140.0     5.459658e+08          2017
# 2000       415004880.0     6.519648e+08          2010
# 3805       335451311.0     7.433000e+08          2019
# 2001       334191110.0     6.912760e+08          2010
# 4401       718732821.0     7.769635e+08          2022
# 3801       543638043.0     1.113305e+09          2019
# 3604       335061807.0     8.169000e+08          2018
# 4404       370270765.0     5.699330e+08          2022
# 3202       486295561.0     5.422753e+08          2016
# 4599       636238421.0     8.094000e+08          2023
# 1400       309420425.0     6.515761e+08          2007
# 4800       506937007.0     5.362432e+08          2024
# 3406         2721100.0     8.676043e+08          2017
# 800        441426807.0     4.875345e+08          2004
# 2403       303003568.0     7.140000e+08          2012
# 1800       749766139.0     1.993811e+09          2009
# 1600       533345358.0     4.705000e+08          2008
# 2603       258366855.0     7.000000e+08          2013
# 1001       380270577.0     4.880820e+08          2005
# 3403       264624300.0     7.701751e+08          2017
# 3408       315058289.0     5.389188e+08          2017
# 2401       304360277.0     8.042007e+08          2012
# 2201       352390543.0     7.714035e+08          2011
# 3804       426829839.0     7.014450e+08          2019

# %%
def is_franchise(title):
    keywords = ['Avengers','Star Wars','Frozen','Jurassic','Minions','Toy Story','Incredibles',
                'Iron Man','Captain','Spider','Batman','Dark Knight','Hobbit','Harry Potter',
                'Transformers','Despicable','Furious','Pirates','Finding','Black Panther','Aquaman','The Lord of the Rings']
    return any(k.lower() in title.lower() for k in keywords)

df['is_franchise'] = df['title'].apply(is_franchise)

franchise_share = (
    df.groupby(['release_year','is_franchise'])['revenue_worldwide']
      .sum().reset_index()
)

# calculate yearly % share
year_total = franchise_share.groupby('release_year')['revenue_worldwide'].transform('sum')
franchise_share['share_pct'] = franchise_share['revenue_worldwide'] / year_total * 100

# plot
#import seaborn as sns, matplotlib.pyplot as plt

plt.figure(figsize=(11,6))
sns.lineplot(data=franchise_share[franchise_share['is_franchise']], 
             x='release_year', y='share_pct', marker='o', label='Franchise Films')
sns.lineplot(data=franchise_share[~franchise_share['is_franchise']], 
             x='release_year', y='share_pct', marker='o', label='Original Films')
plt.title('Franchise vs Original Films: Share of Global Box Office (2000–2024)')
plt.ylabel('Share of Worldwide Revenue (%)')
plt.xlabel('Year')
plt.legend()
plt.tight_layout()
plt.show()

# %%
df_top = pd.read_csv("top_100_highest_rev.csv")
df_top.info()
df_top.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              100 non-null    object
#  1   revenue_worldwide  100 non-null    float64
#  2   revenue_domestic   100 non-null    float64
#  3   revenue_foreign    100 non-null    float64
#  4   release_year       100 non-null    int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 4.0+ KB
#                                         title  revenue_worldwide  \
# 0                           Avengers: Endgame       2.799439e+09
# 1                                      Avatar       2.743578e+09
# 2                    Avatar: The Way of Water       2.320250e+09
# 3  Star Wars: Episode VII 0 The Force Awakens       2.068224e+09
# 4                      Avengers: Infinity War       2.048360e+09
# 5                     Spider0Man: No Way Home       1.912234e+09
# 6                              Jurassic World       1.670401e+09
# 7                               The Lion King       1.656943e+09
# 8                                Inside Out 2       1.595984e+09
# 9                                The Avengers       1.518813e+09
#
#    revenue_domestic  revenue_foreign  release_year
# 0       858373000.0     1.941066e+09          2019
# 1       749766139.0     1.993811e+09          2009
# 2       684075767.0     1.636175e+09          2022
# 3       936662225.0     1.131561e+09          2015
# 4       678815482.0     1.369544e+09          2018
# 5       804793477.0     1.107440e+09          2021
# 6       652270625.0     1.018130e+09          2015
# 7       543638043.0     1.113305e+09          2019
# 8       637852840.0     9.581309e+08          2024
# 9       623357910.0     8.954551e+08          2012

# %%
df.loc[df['title'].str.contains('Widow')]
# Out:
#                                       title  revenue_worldwide  \
# 161                     Widow of St. Pierre          7193889.0
# 469                    K019: The Widowmaker         65716126.0
# 1779                        The Merry Widow         22872698.0
# 2348  Detective K: Secret of Virtuous Widow         32358664.0
# 3695                                 Widows         75984700.0
# 4212                            Black Widow        379751655.0
#
#       revenue_domestic  domestic_pct  revenue_foreign  foreign_pct  \
# 161          3193889.0          44.4        4000000.0         55.6
# 469         35168966.0          53.5       30547160.0         46.5
# 1779               0.0           0.0       22872698.0        100.0
# 2348               0.0           0.0       32358664.0        100.0
# 3695        42402632.0          55.8       33582068.0         44.2
# 4212       183651655.0          48.4      196100000.0         51.6
#
#       release_year   rank                              title_key  \
# 161           2000    NaN                    widow of st. pierre
# 469           2002    NaN                   k019: the widowmaker
# 1779          2008    NaN                        the merry widow
# 2348          2011  148.0  detective k: secret of virtuous widow
# 3695          2018   95.0                                 widows
# 4212          2021   12.0                            black widow
#
#           event_period  is_franchise
# 161           Pre-9/11         False
# 469          Post-9/11         False
# 1779  Financial Crisis         False
# 2348     Stable Growth         False
# 3695     Stable Growth         False
# 4212          Covid-19         False

# %%
def tag_franchise(title):
    franchises = {
        # Major universes
        'Avengers': 'Marvel / Avengers',
        'Captain America': 'Marvel / Avengers',
        'Captain Marvel' : 'Marvel / Avengers',
        'Iron Man': 'Marvel / Avengers',
        'Black Widow',
        'Black Panther': 'Marvel / Avengers',
        'Spider': 'Marvel / Avengers',
        'Star Wars': 'Star Wars',
        'Rogue One' :'Star Wars' ,
        'Batman': 'DC',
        'Justice League': 'DC',
        'Wonder Woman' : 'DC',
        'The Dark Knight' : 'DC',
        'Joker' : 'DC',
        'Aquaman' : 'DC',
        'Deadpool & Wolverine' : 'Marvel / Avengers',
        'Doctor Strange' :'Marvel / Avengers',
        'Thor' : 'Marvel / Avengers',
        'Guardians of the Galaxy' :'Marvel / Avengers',
        'Venom' : 'Marvel / Avengers',

        # Fantasy epics
        'Lord of the Rings': 'Lord of the Rings / Hobbit',
        'Hobbit': 'Lord of the Rings / Hobbit',
        'Harry Potter': 'Harry Potter / Wizarding World',
        'Fantastic Beasts': 'Harry Potter / Wizarding World',

        # Action franchises
        'Fast': 'Fast & Furious',
        'Furious': 'Fast & Furious',
        'The Fate of the Furious': 'Fast & Furious',
        'Jurassic': 'Jurassic',
        'Transformers': 'Transformers',
        'Mission': 'Mission: Impossible',
        'Skyfall' : 'James Bond',
        'Spectre' : 'James Bond',
        'Bond': 'James Bond',

        # Animation powerhouses
        'Frozen': 'Frozen',
        'Toy Story': 'Toy Story',
        'Incredibles': 'Incredibles',
        'Despicable': 'Despicable Me / Minions',
        'Minions': 'Despicable Me / Minions',
        'Finding Dory': 'Pixar Sequel',
        'Finding Nemo' : 'Finding Nemo',
        'Ice Age' : 'Pixar Sequel',
        'Inside Out': 'Pixar Sequel',
        'Coco': 'Original Pixar / Disney',
        'Zootopia': 'Original Pixar / Disney',

        # Disney remakes & studios
        'Beauty and the Beast': 'Disney Remake',
        'Lion King': 'Disney Remake',
        'Aladdin': 'Disney Remake',
        'The Jungle Book' : 'Disney Remake',
        'Little Mermaid': 'Disney Remake',

        # Other universes
        'Avatar': 'Avatar',
        'The Hunger Games' : 'The Hunger Games',
        'Super Mario': 'Nintendo / Mario',
        'Jumanji' : 'Jumanji',
        'Pirates' : 'Pirates of the Caribbean',
        'The Twilight Saga' : 'The Twilight Saga',
        'Shrek' : 'Shrek',
        'Top Gun': 'Legacy Sequel',
    }

    for key, val in franchises.items():
        if key.lower() in title.lower():
            return val
    return "Original"

# %%
df_top['title'].sort_values().unique()
# Out:
# array(['Aladdin', 'Alice in Wonderland', 'Aquaman', 'Avatar',
#        'Avatar: The Way of Water', 'Avengers: Age of Ultron',
#        'Avengers: Endgame', 'Avengers: Infinity War', 'Barbie',
#        'Batman v Superman: Dawn of Justice', 'Beauty and the Beast',
#        'Black Panther', 'Black Panther: Wakanda Forever',
#        'Bohemian Rhapsody', 'Captain America: Civil War',
#        'Captain Marvel', 'Coco', 'Deadpool & Wolverine',
#        'Despicable Me 2', 'Despicable Me 3', 'Despicable Me 4',
#        'Doctor Strange in the Multiverse of Madness',
#        'Fantastic Beasts and Where to Find Them', 'Finding Dory',
#        'Finding Nemo', 'Frozen', 'Frozen II', 'Furious 7',
#        'Guardians of the Galaxy Vol. 2', 'Guardians of the Galaxy Vol. 3',
#        'Harry Potter and the Chamber of Secrets',
#        'Harry Potter and the Deathly Hallows: Part 1',
#        'Harry Potter and the Deathly Hallows: Part 2',
#        'Harry Potter and the Goblet of Fire',
#        'Harry Potter and the Half0Blood Prince',
#        'Harry Potter and the Order of the Phoenix',
#        'Harry Potter and the Prisoner of Azkaban',
#        "Harry Potter and the Sorcerer's Stone", 'Hi, Mom',
#        'Ice Age: Continental Drift', 'Ice Age: Dawn of the Dinosaurs',
#        'Inception', 'Incredibles 2', 'Inside Out', 'Inside Out 2',
#        'Iron Man 3', 'Joker', 'Jumanji: The Next Level',
#        'Jumanji: Welcome to the Jungle', 'Jurassic World',
#        'Jurassic World Dominion', 'Jurassic World: Fallen Kingdom',
#        'Minions', 'Minions: The Rise of Gru', 'Oppenheimer',
#        "Pirates of the Caribbean: At World's End",
#        "Pirates of the Caribbean: Dead Man's Chest",
#        'Pirates of the Caribbean: On Stranger Tides',
#        'Rogue One: A Star Wars Story', 'Shrek 2', 'Shrek the Third',
#        'Skyfall', 'Spectre', 'Spider0Man', 'Spider0Man 3',
#        'Spider0Man: Far from Home', 'Spider0Man: Homecoming',
#        'Spider0Man: No Way Home',
#        'Star Wars: Episode III 0 Revenge of the Sith',
#        'Star Wars: Episode IX 0 The Rise of Skywalker',
#        'Star Wars: Episode VII 0 The Force Awakens',
#        'Star Wars: Episode VIII 0 The Last Jedi', 'The Avengers',
#        'The Battle at Lake Changjin', 'The Dark Knight',
#        'The Dark Knight Rises', 'The Fate of the Furious',
#        'The Hobbit: An Unexpected Journey',
#        'The Hobbit: The Battle of the Five Armies',
#        'The Hobbit: The Desolation of Smaug',
#        'The Hunger Games: Catching Fire', 'The Jungle Book',
#        'The Lion King',
#        'The Lord of the Rings: The Fellowship of the Ring',
#        'The Lord of the Rings: The Return of the King',
#        'The Lord of the Rings: The Two Towers', 'The Secret Life of Pets',
#        'The Super Mario Bros. Movie',
#        'The Twilight Saga: Breaking Dawn 0 Part 2', 'Thor: Ragnarok',
#        'Top Gun: Maverick', 'Toy Story 3', 'Toy Story 4',
#        'Transformers: Age of Extinction',
#        'Transformers: Dark of the Moon',
#        'Transformers: Revenge of the Fallen', 'Venom', 'Wolf Warrior 2',
#        'Wonder Woman', 'Zootopia'], dtype=object)

# %%
df_top.head()
# Out:
#                                         title  revenue_worldwide  \
# 0                           Avengers: Endgame       2.799439e+09
# 1                                      Avatar       2.743578e+09
# 2                    Avatar: The Way of Water       2.320250e+09
# 3  Star Wars: Episode VII 0 The Force Awakens       2.068224e+09
# 4                      Avengers: Infinity War       2.048360e+09
#
#    revenue_domestic  revenue_foreign  release_year          franchise
# 0       858373000.0     1.941066e+09          2019  Marvel / Avengers
# 1       749766139.0     1.993811e+09          2009             Avatar
# 2       684075767.0     1.636175e+09          2022             Avatar
# 3       936662225.0     1.131561e+09          2015          Star Wars
# 4       678815482.0     1.369544e+09          2018  Marvel / Avengers

# %%
df_top['franchise'] = df_top['title'].apply(tag_franchise)
summary = (
    df_top.groupby('franchise')['revenue_worldwide']
    .agg(['count', 'sum'])
    .sort_values(by='sum', ascending=False)
)
summary['share_pct'] = summary['sum'] / summary['sum'].sum() * 100
summary.head(15)
# Out:
#                                 count           sum  share_pct
# franchise
# Marvel / Avengers                  20  2.453127e+10  21.922270
# Original                            9  8.649041e+09   7.729179
# Harry Potter / Wizarding World      9  8.539016e+09   7.630856
# Star Wars                           5  6.399318e+09   5.718724
# DC                                  6  6.016821e+09   5.376907
# Lord of the Rings / Hobbit          6  5.863494e+09   5.239887
# Pixar Sequel                        5  5.246781e+09   4.688764
# Avatar                              2  5.063828e+09   4.525269
# Disney Remake                       4  4.937709e+09   4.412563
# Despicable Me / Minions             5  4.913705e+09   4.391112
# Jurassic                            3  3.980847e+09   3.557467
# Pirates of the Caribbean            3  3.072890e+09   2.746075
# Transformers                        3  3.064152e+09   2.738267
# Fast & Furious                      2  2.751053e+09   2.458467
# Frozen                              2  2.730829e+09   2.440394

# %%
summary = (df_top.groupby('franchise')['revenue_worldwide']
             .agg(['count','sum'])
             .sort_values(by='sum', ascending=False))
summary['share_pct'] = summary['sum'] / summary['sum'].sum() * 100
summary.head(15)
# Out:
#                             count           sum  share_pct
# franchise
# Original                       45  4.360183e+10  38.964598
# Marvel / Avengers               9  1.347192e+10  12.039127
# Star Wars                       5  6.399318e+09   5.718724
# Lord of the Rings / Hobbit      6  5.863494e+09   5.239887
# Spider-Man                      5  5.641020e+09   5.041074
# Avatar                          2  5.063828e+09   4.525269
# Despicable Me / Minions         5  4.913705e+09   4.391112
# Jurassic                        3  3.980847e+09   3.557467
# Disney Remake                   3  3.971158e+09   3.548809
# Pixar Sequel                    3  3.482849e+09   3.112434
# Pirates of the Caribbean        3  3.072890e+09   2.746075
# Transformers                    3  3.064152e+09   2.738267
# Frozen                          2  2.730829e+09   2.440394
# Toy Story                       2  2.140364e+09   1.912728
# Nintendo / Mario                1  1.361992e+09   1.217139

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=summary.head(10).reset_index(),
            y='franchise', x='sum', palette='crest')
plt.title('Top 10 Franchises by Global Box Office (Top 100 Films)')
plt.xlabel('Total Worldwide Revenue ($)')
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\dirtd\AppData\Local\Temp\ipykernel_28024\2121679958.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=summary.head(10).reset_index(),

# %%
share = df_top.assign(type=np.where(df_top['franchise']=='Original','Original','Franchise'))
share = share.groupby('type')['revenue_worldwide'].sum()
share.plot(kind='pie', autopct='%1.1f%%', startangle=90, figsize=(5,5),
           colors=['#8ecae6','#023047'], ylabel='')
plt.title('Franchise vs Original Share of Top 100 Global Box Office')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df_top, x='release_year', y='revenue_worldwide', color='#219ebc')
plt.title('Revenue Distribution of Top 100 Films by Release Year')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df_top['is_franchise'] = df_top['franchise'].apply(lambda x: 'Franchise' if x != 'Original' else 'Original')

avg_rev = (
    df_top.groupby(['release_year','is_franchise'])['revenue_worldwide']
    .mean()
    .reset_index()
)
df_top
# Out:
#                                          title  revenue_worldwide  \
# 0                            Avengers: Endgame       2.799439e+09
# 1                                       Avatar       2.743578e+09
# 2                     Avatar: The Way of Water       2.320250e+09
# 3   Star Wars: Episode VII 0 The Force Awakens       2.068224e+09
# 4                       Avengers: Infinity War       2.048360e+09
# ..                                         ...                ...
# 95                                        Coco       8.146412e+08
# 96                             Shrek the Third       8.133674e+08
# 97                             Despicable Me 4       8.085376e+08
# 98                     Jumanji: The Next Level       8.016939e+08
# 99    Harry Potter and the Prisoner of Azkaban       7.956341e+08
#
#     revenue_domestic  revenue_foreign  release_year  \
# 0        858373000.0     1.941066e+09          2019
# 1        749766139.0     1.993811e+09          2009
# 2        684075767.0     1.636175e+09          2022
# 3        936662225.0     1.131561e+09          2015
# 4        678815482.0     1.369544e+09          2018
# ..               ...              ...           ...
# 95       210460015.0     6.041812e+08          2017
# 96       322719944.0     4.906474e+08          2007
# 97       332583715.0     4.759539e+08          2024
# 98       320314960.0     4.813790e+08          2019
# 99       249541069.0     5.460930e+08          2004
#
#                          franchise is_franchise
# 0                Marvel / Avengers    Franchise
# 1                           Avatar    Franchise
# 2                           Avatar    Franchise
# 3                        Star Wars    Franchise
# 4                Marvel / Avengers    Franchise
# ..                             ...          ...
# 95         Original Pixar / Disney    Franchise
# 96                           Shrek    Franchise
# 97         Despicable Me / Minions    Franchise
# 98                         Jumanji    Franchise
# 99  Harry Potter / Wizarding World    Franchise
#
# [100 rows x 7 columns]

# %%
df_top[df_top['is_franchise'] == 'Original'][['title','is_franchise']]
# Out:
#                           title is_franchise
# 13                       Barbie     Original
# 46          Alice in Wonderland     Original
# 51                  Oppenheimer     Original
# 54              The Jungle Book     Original
# 66            Bohemian Rhapsody     Original
# 67  The Battle at Lake Changjin     Original
# 75      The Secret Life of Pets     Original
# 77                 Finding Nemo     Original
# 78               Wolf Warrior 2     Original
# 90                    Inception     Original
# 92                      Hi, Mom     Original

# %%
df_conc = (
    df_top.sort_values(by='revenue_worldwide', ascending=False)
           .assign(cum_revenue=lambda x: x['revenue_worldwide'].cumsum(),
                   share=lambda x: x['revenue_worldwide'] / x['revenue_worldwide'].sum(),
                   cum_share=lambda x: x['share'].cumsum(),
                   rank=lambda x: np.arange(1, len(x)+1))
)
plt.figure(figsize=(10,6))
plt.plot(df_conc['rank'], df_conc['cum_share']*100, marker='o', color='teal')
plt.axhline(80, color='r', linestyle='--', alpha=0.5)
plt.axvline(20, color='r', linestyle='--', alpha=0.5)
plt.text(22, 82, "≈ Top 20 films\n≈ 80% of revenue", color='r')

plt.title("Revenue Concentration: Top 100 Highest-Grossing Films")
plt.xlabel("Film Rank (1 = Highest Grossing)")
plt.ylabel("Cumulative Share of Global Revenue (%)")
plt.grid(alpha=0.3)
plt.show()

# %%
df.head()
# Out:
#                     title  revenue_worldwide  revenue_domestic  domestic_pct  \
# 0  Mission: Impossible II        546388108.0       215409889.0          39.4
# 1               Gladiator        460583960.0       187705427.0          40.8
# 2               Cast Away        429632142.0       233632142.0          54.4
# 3         What Women Want        374111707.0       182811707.0          48.9
# 4                Dinosaur        349822765.0       137748063.0          39.4
#
#    revenue_foreign  foreign_pct  release_year  rank               title_key  \
# 0      330978219.0         60.6          2000   NaN  mission: impossible ii
# 1      272878533.0         59.2          2000   NaN               gladiator
# 2      196000000.0         45.6          2000   NaN               cast away
# 3      191300000.0         51.1          2000   NaN         what women want
# 4      212074702.0         60.6          2000   NaN                dinosaur
#
#   event_period  is_franchise
# 0     Pre-9/11         False
# 1     Pre-9/11         False
# 2     Pre-9/11         False
# 3     Pre-9/11         False
# 4     Pre-9/11         False

# %%
df[df['release_year'] >= 2020]['title'].sort_values().unique() #'Post-9/11'
# Out:
# array(['###############################################################################################################################################################################################################################################################',
#        '#Alive', '10 Days with Dad', '10 Lives', '100% Wolf',
#        '12.12: The Day', '18Ã\x972 Beyond Youthful Days', '1921',
#        '2024 Oscar Nominated Short Films: Documentary', '30 jours max',
#        '3391 Kilometres', '365 Days', '65', '777 Charlie', '80 for Brady',
#        '99.9 Criminal Lawyer: The Movie', 'A Guilty Conscience',
#        'A Haunting in Venice', 'A Little Red Flower',
#        'A Little Something Extra', 'A Man Called Otto',
#        'A Million Minutes', 'A Moroccan Affair', 'A Piece of Cake',
#        'A Quiet Place Part II', 'A Quiet Place: Day One',
#        "A Smile Doesn't Lie", 'A Strange House', "A Writer's Odyssey",
#        'AI Amok', 'Aavesham', 'Abigail', 'About My Father',
#        'Abudeka Is Back', 'Acharya', 'Adu', 'After Death',
#        'After Ever Happy', 'After Everything', 'After We Collided',
#        'After We Fell', 'Aftersun', "Agent Backkom: King's Bear", 'Ainbo',
#        'Air', 'Ala Vaikunthapurramuloo', 'Alibi.com 2', 'Alienoid',
#        'Alienoid: The Return to the Future', 'Aline',
#        'All About My Mother', 'All Your Faces', 'All of Us Strangers',
#        'Ambulance', 'American Fiction', 'American Underdog', 'Amsterdam',
#        'Anatomy of a Fall', 'And So the Baton Is Passed', 'Animal',
#        'Anita', 'Another Round', 'Ant0Man and the Wasp: Quantumania',
#        'Antebellum', 'Antlers', 'Anweshippin Kandethum', 'Anyone But You',
#        'April, Come She Will', 'Aquaman and the Lost Kingdom',
#        'Arashi Anniversary Tour 5 x 20 Film: Record of Memories',
#        "Are You There God? It's Me, Margaret.", 'Argylle',
#        'Arthur the King', 'Article 370',
#        'Asterix & Obelix: The Middle Kingdom', 'Asteroid City',
#        'Autumn and the Black Jaguar', 'Avatar 2021 Re0release',
#        'Avatar 2022 Re0release', 'Avatar: The Way of Water',
#        'Ayyappanum Koshiyum',
#        'BTS Permission to Dance on Stage 0 Seoul: Live Viewing',
#        'BTS: Yet to Come in Cinemas', 'Baaghi 3', 'Baba Parasi', 'Babes',
#        'Baby boom, or Eggnog 5', 'Babylon', 'Bachchhan Paandey',
#        'Back to Black', 'Back to the Wharf', 'Bad Boys for Life',
#        'Bad Boys: Ride or Die', 'Baghead', 'Baragaki: Unbroken Samurai',
#        'Barbarian', 'Barbie', 'Bath Buddy', 'Be Somebody', 'Beast',
#        'Beasts Clawing at Straws', 'Beau Is Afraid', 'Belfast', 'Belle',
#        'Bergen', 'Bheemla Nayak', 'Bheeshma', 'Bhool Bhulaiyaa 2',
#        'Big Red Envelope', 'Bigfoot Family', 'Bill & Ted Face the Music',
#        'Birds of Prey', 'Black Adam', 'Black Box',
#        'Black Panther 2020 Re0release', 'Black Panther: Wakanda Forever',
#        'Black Widow', 'Blacklight', 'Blood Moon Party', 'Bloodshot',
#        'Blue Beetle', 'Blue Lock: Episode Nagi', 'Bob Marley: One Love',
#        'Bocchi the Rock! Re:', 'Bodies Bodies Bodies',
#        'Bohemian Rhapsody 2020 Re0release', 'BolÃ©ro', 'Bones and All',
#        'Book Club: The Next Chapter', 'Boonie Bears: The Wild Life',
#        'Borderlands', 'Bottoms', 'Boy Kills World',
#        'Brahmastra Part One: Shiva', 'Brahms: The Boy II',
#        'Break Through the Darkness', 'Break the Silence: The Movie',
#        'Breaking Point', 'Broker', 'Bros', "Budda. Dzieciak '98",
#        'Bullet Train', 'Buzz House: The Movie', 'Bye Bye Morons',
#        'Cabrini', 'Calendar Girls', 'Candyman', 'Cat and Dog',
#        'Cats & Dogs 3: Paws Unite', 'Cats in the Museum',
#        'Caught in Time', 'Caution, Hazardous Wife: The Movie',
#        'Challengers', 'Championext', 'Champions', 'Chantal in Fairyland',
#        'Chaos Walking', 'Character', 'Chebi: My Fluffy Friend',
#        'Checker Tobi und die Reise zu den fliegenden FlÃ¼ssen',
#        'Chhapaak', 'Chickenhare and the Hamster of Darkness',
#        'Chinese Doctors', 'Christmas with the Chosen: The Messengers',
#        'Cindy La Regia', 'Citizen of a Kind', 'Civil War',
#        'Cliff Walkers', 'Clifford the Big Red Dog', 'Cloudy Mountain',
#        'Cobweb', 'Cocaine Bear', 'Cocorico', 'Collectors',
#        'Columbia 100th Anniversary Series Columbia 100th Anniversary Series',
#        'Come Play', 'Concrete Utopia',
#        'Confidential Assignment 2: International', 'Contra',
#        'Crayon Shin0chan: Mononoke Ninja Chinpuden',
#        'Crayon Shin0chan: Shrouded in Mystery! The Flowers of Tenkazu Academy',
#        'Creed III', 'Crew', 'Cruella', 'Cry Macho', 'Cuckoo',
#        'DC League of Super0Pets', 'Daaaaaali!', 'Dad', "Dad, I'm Sorry",
#        'De Gaulle', 'Deadpool & Wolverine', 'Dear Evan Hansen',
#        'Dear Family', 'Death on the Nile', 'Decibel', 'Decision to Leave',
#        'Delicious', 'Deliver Us from Evil',
#        'Demon Slayer: Kimetsu No Yaiba - To the Hashira Training',
#        'Demon Slayer: Kimetsu No Yaiba 0 To the Swordsmith Village',
#        'Demon Slayer: Kimetsu no Yaiba 0 The Movie: Mugen Train',
#        'Despicable Me 4', 'Detective Chinatown 3',
#        'Detective Conan vs. Kid the Phantom Thief',
#        'Detective Conan: Black Iron Submarine',
#        'Detective Conan: The Bride of Halloween',
#        'Detective Conan: The Million-Dollar Pentagram',
#        'Detective Conan: The Scarlet Alibi',
#        'Detective Conan: The Scarlet Bullet', 'Devotion',
#        'Die KÃ¤nguru0Chroniken', 'Die drei ??? 0 Erbe des Drachen',
#        'Digimon Adventure: Last Evolution Kizuna', 'Divorce Club',
#        'Doctor Strange in the Multiverse of Madness', 'Dog', 'Dolittle',
#        'Don', "Don't Breathe 2", "Don't Call it Mystery: The Movie",
#        "Don't Worry Darling",
#        "Doraemon the Movie: Nobita's Earth Symphony",
#        "Doraemon the Movie: Nobita's Little Star Wars 2021",
#        "Doraemon the Movie: Nobita's New Dinosaur",
#        "Doraemon the Movie: Nobita's Sky Utopia", 'Downhill',
#        'Downton Abbey: A New Era', 'Dr. Cheon and Lost Talisman',
#        "Dr. Coto's Clinic", 'Dragon Ball Super: Super Hero',
#        'Dragon Rider', 'Dragonkeeper', 'Dream', 'Dream Scenario',
#        'Drive My Car', 'Drive-Away Dolls', 'Ducobu 3',
#        'Ducobu 4 President', 'Ducobu passe au vert!', 'Dumb Money',
#        'Dune: Part One', 'Dune: Part One 2024 Re-release',
#        'Dune: Part Two', 'Dungeons & Dragons: Honor Among Thieves',
#        'Dunki', 'Easter Sunday', 'Eiffel',
#        'Eiga Sumikkogurashi: Aoi tsukiyo no mahÃ´ no ko', 'El Roomie',
#        'Elemental', 'Eltilerin Savasi', 'Elvis', 'Emergency Declaration',
#        'Emma.', 'Empire of Light', 'Encanto', 'End Game', 'Epic Tails',
#        'Escape', 'Escape Room: Tournament of Champions',
#        'Escape from Mogadishu', 'Eternals',
#        'Evangelion: 3.0+1.01 Thrice Upon a Time',
#        'Even If This Love Disappears from the World Tonight',
#        'Everything Everywhere All at Once', 'Evil Dead Rise', 'Exhuma',
#        'Ezra', 'F3: Fun and Frustration', 'F9: The Fast Saga',
#        'Face Off 6: The Ticket of Destiny', 'Face Off 7: One Wish',
#        'Fall', 'Family Affairs',
#        'Fantastic Beasts: The Secrets of Dumbledore', 'Fantasy Island',
#        'Fast X', 'Fatale',
#        "Fate/stay night [Heaven's Feel] III. spring song",
#        'Father & Soldier', 'Father Stu', 'Father There Is Only One 3',
#        'Father There is Only One 2', 'Father There is Only One 4',
#        'Ferrari', 'Fighter', 'Finnick', 'Firestarter',
#        "Five Nights at Freddy's", 'Fly Me to the Moon', 'Following',
#        'Force of Nature: The Dry 2', 'Fragments of the Last Will',
#        'Freaky', 'Free Guy', 'Freelance',
#        "From Today, It's My Turn: The Movie",
#        'Frozen 2023 Re0release (Sing 0A0Long)', 'FrÃ¨res', 'Fukushima 50',
#        'Furiosa: A Mad Max Saga', 'GHOST: Rite Here Rite Now',
#        'Gap Lai Chi Bau', 'Ghostbusters: Afterlife',
#        'Ghostbusters: Frozen Empire', 'Gintama: The Final',
#        'Girls to Buy', 'Glass Onion', 'Godai 0 The Wunderkind',
#        'Godfather', 'Godzilla Minus One', 'Godzilla vs. Kong',
#        'Godzilla x Kong: The New Empire', 'Golden Kamuy', 'Gondola',
#        'Good Luck to You, Leo Grande', 'Gran Turismo',
#        'Gravity 2020 Re0release',
#        'Gravity 2023 Re0release (10th Anniversary)', 'Green Snake',
#        'Greenland', 'Gretel & Hansel', 'Guardians of the Galaxy Vol. 3',
#        'Guest from the Future', 'Guglhupfgeschwader',
#        "Guy Ritchie's the Covenant", 'Haikyuu!! The Dumpster Battle',
#        'Halloween Ends', 'Halloween Kills', 'Hammamet', 'Handsome Guys',
#        'Hansan: Rising Dragon', 'Hard Hit',
#        'Harold and the Purple Crayon',
#        "Harry Potter and the Sorcerer's Stone 2020 Re0release",
#        "Harry Potter and the Sorcerer's Stone 2021 Re0release",
#        'Haunted Mansion', 'Hero', 'Hi, Mom', 'Hijack 1971',
#        'His Only Son', 'Hit Man', "Hitman's Wife's Bodyguard",
#        'Hitman: Agent Jun', 'Hocus Pocus 2020 Re0release',
#        'Home Sweet Home', 'Honest Candidate', 'Honest Thief',
#        'Honey Lemon Soda', 'Honey Sweet',
#        'Horizon: An American Saga - Chapter 1',
#        'Hostage: Missing Celebrity', 'Hotel Belgrade', 'House Party',
#        'House of Gucci', 'How I Became a Gangster',
#        'How to Be a Good Wife',
#        'How to Make Millions Before Grandma Dies', 'Howling Village',
#        'Hunt', 'Hypnotic',
#        "I Don't Have Any Money Left in My Retirement Account",
#        'I Hate Summer', 'I Saw the TV Glow', 'I Still Believe',
#        'I Wish I Could Meet You Again on the Hill Where That Flower Blooms (2023)',
#        'I soliti idioti 3: Il ritorno', 'I.S.S.',
#        'IDOLiSH7 Movie: LIVE 4bit 0 BEYOND THE PERiOD', 'IF', 'Ice 2',
#        'Il grande giorno', 'Imaginary', 'Immaculate',
#        'Impractical Jokers: The Movie', 'In a Violent Nature',
#        'In the Heights', 'Inception 10th Anniversary re0release',
#        'Indiana Jones and the Dial of Destiny', 'Innocence',
#        'Inside Out 2', 'Insidious: The Red Door',
#        'Interstellar 2020 Re0release', 'It Ends with Us',
#        'Jackass Forever', 'Jatt & Juliet 3', 'Jawan', 'Jeanne du Barry',
#        'Jesus Revolution', 'Jesus Thirsts: The Miracle of the Eucharist',
#        'Jiang Ziya', 'Jim Button and the Wild 13', 'John Wick: Chapter 4',
#        'Joy Ride', 'Judas and the Black Messiah', 'Jug Jugg Jeeyo',
#        'Jujutsu Kaisen 0', 'Jungle Bunch: Operation Meltdown',
#        'Jungle Cruise', 'Jurassic World Dominion', 'K.G.F: Chapter 2',
#        'Kaamelott: First Installment', 'Kaguya0sama: Love Is War',
#        'Kaiji: Final Game', 'Kaiserschmarrndrama', 'Kalki 2898 AD',
#        'Kandahar', "Kensuke's Kingdom", 'Killers of the Flower Moon',
#        'Kinds of Kindness', 'King Richard', 'Kingdom 2: Far and Away',
#        'Kingdom 3: The Flame of Destiny',
#        'Kingdom 4: Return of the Great General',
#        'Kingdom of the Planet of the Apes',
#        'Klassikokkutulek 2: Pulmad ja matused', 'Kleks Academy',
#        'Knock at the Cabin', "KolpaÃ§ino 4 4'lÃ¼k", 'Krack',
#        'Kung Fu Panda 4', 'Kyu Ju Sai. Nani ga Medetai',
#        "L'appel de la forÃªt", 'La familia BenetÃ³n',
#        'La petite vadrouille',
#        "La planÃ¨te des singes, une odyssÃ©e de l'espÃ¨ce",
#        'Laal Singh Chaddha', 'Laid0Back Camp Movie', 'Land of Bad',
#        'Land of Legends', 'Last Letter', 'Last Night in Soho',
#        'Late Night with the Devil', 'Leap', 'Legend No. 17',
#        'Les Tuche 4', 'Les blagues de Toto', 'Lesson in Murder',
#        'Let Him Go', "Let's Go! Anpanman: Baikinman and Lulun",
#        'Letuchiy korabl', 'Licorice Pizza', 'Life Is Beautiful',
#        'Lightyear', 'Like a Boss', 'Lindenberg! Mach dein Ding',
#        'Lisa Frankenstein', 'Listy do M. 5', 'Little Canned Men',
#        'Living', 'Lohusa', 'Longlegs', 'Look Back', 'Lost Illusions',
#        'Love Aaj Kal', 'Love Again', 'Love Letter 2021 Re0release',
#        'Love Lies Bleeding', 'Love Me, Love Me Not', 'Love Reset',
#        'Love Will Tear Us Apart', 'Love You Forever', 'Lovesick Ellie',
#        'Loving Bali', 'Luca', 'Lucky Winners', 'Lyle, Lyle, Crocodile',
#        'Lyod 3', 'M3GAN', 'MaXXXine', 'Madame Web',
#        'Made in Abyss: Dawn of the Deep Soul', "Magic Mike's Last Dance",
#        'Mai', 'Maison de retraite', 'Maison de retraite 2',
#        'Major Grom: The Game', 'Malang', 'MalasaÃ±a 32', 'Malignant',
#        'Mama Weed', 'Mamma Mia! 2020 Re0release',
#        'Mamma Mia! Here We Go Again 2020 Re0release', 'Man in Love',
#        'Manjummel Boys', 'Manta, Manta: Legacy',
#        'Manyunya. Priklyucheniya v Moskve', 'Maria Montessori',
#        'Marry Me', 'Masked Ward', 'Masquerade Night', 'Master',
#        'Matching', 'Matilda: The Musical', 'Mavka: The Forest Song',
#        'Mayday', 'Me Contro Te - Il film: Operazione Spie',
#        'Me contro Te 0 Il film: La vendetta del Signor S', 'Mean Girls',
#        'Meet the Leroys', 'Meg 2: The Trench', 'Memory', 'Men',
#        'Menudas piezas', 'Midnight Swan', 'Migration', 'Military Wives',
#        'Minari', 'Minions: The Rise of Gru',
#        'Miraculous: Ladybug & Cat Noir, the Movie', 'Missing',
#        'Mission: Impossible 0 Dead Reckoning Part One',
#        'Mobile Suit Gundam Seed Freedom', 'Mobile Suit Gundam: Hathaway',
#        'Monkey Man', 'Monster', 'Monster Hunter', 'Moon Man',
#        'Moonage Daydream', 'Moonbound', 'Moonfall', 'Morbius',
#        'Mortal Kombat', 'Mrs. Harris Goes to Paris', 'Mulan', 'Mummies',
#        'My Big Fat Greek Wedding 3', "My Boyfriend's Meds",
#        'My Country, My Parents', 'My Donkey, My Lover & I',
#        'My Happy Marriage', "My Hero Academia: World Heroes' Mission",
#        'My Love', 'My Mom is a Character 3', 'My People, My Homeland',
#        'My Spy', "N'avoue jamais", 'Napoleon',
#        'NausicaÃ¤ of the Valley of the Wind 2020 Re0release',
#        'Never Stop', 'New Gods: Nezha Reborn', 'New Happy Dad and Son 4',
#        'News of the World', 'Next Goal Wins', 'Nice View', 'Night Swim',
#        'Nightlife', 'Nightmare Alley', 'No Escapes', 'No Hard Feelings',
#        'No Time to Die', 'No Way Up', "Noah's Ark", 'Nobody', 'Nomadland',
#        'Nope', 'Noryang: Deadly Sea', 'November',
#        'OSS 117: From Africa with Love', 'Okay Madam', 'Old',
#        'On Your Mark', 'On the Line', 'On the Wandering Paths',
#        'Once Upon a Time in Hong Kong', 'One Life', 'One Piece Film: Red',
#        'One Second', 'Onegin', 'Only 3 Days Left', 'Onmyoji Zero',
#        'Onward', 'Operation Fortune: Ruse de Guerre',
#        'Operation Mincemeat', 'Oppenheimer', 'Ordinary Angels',
#        'Orphan: First Kill', 'Osomatsusan the Movie 2022 Re0release',
#        'Our Folks: The Beginning', 'PAW Patrol: The Mighty Movie',
#        'PAW Patrol: The Movie', 'Panga', 'Parallel Mothers',
#        'Pare parecchio Parigi', 'Past Lives', 'Pathaan', 'Pawn',
#        'Paws of Fury: The Legend of Hank', 'Pearl', 'Peninsula',
#        "Peppa's Cinema Party", 'Perfect Days', 'Persian Lessons',
#        'Peter Rabbit 2: The Runaway', 'Phases of the Moon',
#        "Pil's Adventures", 'Pilot', 'Plane',
#        'PokÃ©mon the Movie: Secrets of the Jungle',
#        'Ponniyin Selvan: Part I', 'Poor Things',
#        'Poupelle of Chimney Town', 'PreCure All Stars F',
#        'Prey for the Devil', 'Princess Mononoke Studio Ghibli Fest 2020',
#        'Priscilla', 'Project Silence', 'Promising Young Woman',
#        'Psy 3: W imie zasad', 'Pushpa: The Rise 0 Part 1',
#        'Puss in Boots: The Last Wish', 'RRR',
#        'Rabbit Academy: Mission Eggpossible', 'Radhe Shyam', 'Radical',
#        'Rafadan Tayfa 4: HayrimatÃ¶r', 'Raging Fire', 'Railway Heroes',
#        'Ransomed', 'Raya and the Last Dragon', 'Re/Member',
#        'Realm of Terracotta', 'Redeeming Love', 'Rehragout0Rendezvous',
#        'Reminiscence', 'Renaissance: A Film by BeyoncÃ©', 'Renfield',
#        'Resident Evil: Welcome to Raccoon City', 'Respect', 'Retribution',
#        'Rheingold', 'Ride On', 'Rise', "Ron's Gone Wrong",
#        'Ruby Gillman: Teenage Kraken', 'Run',
#        'Rurouni Kenshin: Final Chapter Part I 0 The Final',
#        'Rurouni Kenshin: Final Chapter Part II 0 The Beginning',
#        "SUGA: Agust D Tour 'D-DAY' the Movie", 'Salaar', 'Saltburn',
#        'Samjin Company English Class', 'Samrat Prithviraj',
#        "Samurai Beyond Admiration Record to the World's Best",
#        'Sarileru Neekevvaru', 'Sarkaru Vaari Paata', 'Saw X',
#        'Schemes in Antiques', 'School of Magical Animals',
#        'School of Magical Animals 2', 'Scoob!', 'Scream', 'Scream VI',
#        'Secret Zoo', 'See How They Run', 'Serial (Bad) Weddings 3',
#        'Shang0Chi and the Legend of the Ten Rings',
#        'Shazam! Fury of the Gods', 'She Said',
#        'Shin Jigen! Crayon Shin0chan the Movie', 'Shin Kamen Rider',
#        'Shin Ultraman',
#        'Shinchan: Crash! Scribble Kingdom and Almost Four Heroes',
#        'Shock Wave 2', 'Shotgun Wedding', 'Shrek 2 2024 Re-release',
#        'Shubh Mangal Zyada Saavdhan', 'Siccin 7', 'Sight',
#        'Signal: The Movie', 'Silent Love', 'Silent Night',
#        'Silent Parade', 'Simone: Woman of the Century', 'Simply Black',
#        'Sing 2', 'Sinkhole', 'Sister', 'Sisu', 'Sleep', 'Smack Dab Kakha',
#        'Smile', 'Smugglers', 'Snake Eyes', 'Someone Like You',
#        'Something About Love', 'Son of a Rich 2', 'Sonic the Hedgehog',
#        'Sonic the Hedgehog 2', 'Soul', 'Soul Snatcher',
#        'Sound of Freedom', 'Sound of Hope: The Story of Possum Trot',
#        'Space Jam: A New Legacy', 'Spencer',
#        'Spider0Man: Across the Spider0Verse', 'Spider0Man: No Way Home',
#        'Spider0Man: No Way Home 2022 Re0release', 'Spiral',
#        'Spirit Untamed', 'Spirited Away Studio Ghibli Fest 2020',
#        'Spy x Family Code: White', 'Spycies', 'Stand by Me',
#        'Stand by Me Doraemon 2',
#        'Star Wars: Episode I - The Phantom Menace 2024 Re-release',
#        'Stigmatized Properties', 'Stillwater', 'Stolen Identity 2',
#        'Strange World', 'Strays', 'Street Dancer 3D', 'Streltsov',
#        'Sun and Concrete', 'Sunny Sisters', 'Superwho?', 'Suzume',
#        'Sword Art Online the Movie: Progressive 0 Scherzo of Deep Night',
#        'Sword Art Online: Progressive 0 Aria of a Starless Night',
#        'Table for Six', 'Table for Six 2',
#        'Tad the Lost Explorer and the Emerald Tablet',
#        'Takizawa Enbujo Zero', 'Talk to Her Undated France Release',
#        'Talk to Me', 'Tanhaji: The Unsung Warrior', 'Tarot',
#        'Taylor Swift: The Eras Tour',
#        'Teenage Mutant Ninja Turtles: Mutant Mayhem', 'Tenet',
#        'Terrifier 2', 'Thanksgiving',
#        'That Time I Got Reincarnated as a Slime the Movie: Scarlet Bond',
#        'The (UN)perfect Guy', 'The 355', 'The Addams Family 2',
#        'The Amazing Maurice', 'The Animal Kingdom', 'The Asadas',
#        'The Bad Guys', 'The Banshees of Inisherin', 'The Batman',
#        'The Battle at Lake Changjin', 'The Beasts', 'The Beekeeper',
#        'The Best Years', 'The Bikeriders',
#        'The Birth of Kitaro: Mystery of GeGeGe', 'The Birth of Korea',
#        'The Black Phone', 'The Blackening', 'The Blind',
#        "The Bob's Burgers Movie", "The Bodin's in the Land of Smile",
#        'The Boogeyman', 'The Book of Clarence',
#        'The Boss Baby 2: Family Business', 'The Boy and the Heron',
#        'The Boys in the Boat', 'The Bremen Town Musicians',
#        'The Buried Talent', 'The Call of the Wild', 'The Challenge',
#        'The Chosen Season 3: Episode 1 & 2',
#        'The Chosen: S4 Episodes 1-3', 'The Chosen: S4 Episodes 4-6',
#        'The Chosen: S4 Episodes 7-8', 'The Closet', 'The Color Purple',
#        'The Confidence Man JP: Episode of the Hero',
#        'The Confidence Man JP: Princess',
#        'The Conjuring: The Devil Made Me Do It',
#        'The Count of Monte-Cristo', 'The Courier', 'The Creator',
#        'The Crime Is Mine', 'The Croods: A New Age',
#        'The Day We Lit Up the Sky', 'The Door Lock', 'The Dry',
#        'The Duke', 'The Eight Hundred', 'The Eight Mountains',
#        'The Eleventh Chapter', 'The End of Endless Love',
#        'The Equalizer 3', 'The Exorcism', 'The Exorcist: Believer',
#        'The Expendables 4', 'The Fabelmans',
#        "The Fable: The Killer Who Doesn't Kill", 'The Fabulous Four',
#        'The Fall Guy', 'The Father', 'The First Omen',
#        'The First Slam Dunk', 'The Flash', 'The Forever Purge',
#        'The French Dispatch', 'The Garfield Movie', 'The Goat Life',
#        'The Good Teacher', 'The Great Escaper', 'The Green Knight',
#        'The Heist of the Century', 'The Holdovers', 'The House of No Man',
#        'The Hunger Games: The Ballad of Songbirds & Snakes', 'The Hunt',
#        'The Ice Road', 'The Innocent', 'The Invisible Man',
#        'The Invitation', 'The Iron Claw', 'The Kashmir Files',
#        'The Kids Are Alright 2', "The King's Man", 'The Last 10 Years',
#        'The Last Duel', 'The Last Voyage of the Demeter',
#        'The Last Warrior: A Messenger of Darkness',
#        'The Last Warrior: Root of Evil',
#        'The Legacy of Dr. Death: Black File', 'The Legend & Butterfly',
#        'The Legend of Maula Jatt', 'The Lion King 2020 Re0release',
#        'The Little Mermaid', 'The Little Things', 'The Long Game',
#        'The Lord of the Rings: The Fellowship of the Ring 2021 Re0release',
#        'The Lord of the Rings: The Fellowship of the Ring 2024 Re-release',
#        'The Lord of the Rings: The Two Towers 2024 Re-release',
#        'The Lost City', 'The Lost Prince', 'The Machine',
#        'The Man Standing Next', 'The Many Saints of Newark',
#        'The Marksman', 'The Marriage Escape', 'The Marvels',
#        'The Master and Margarita', 'The Matrix Resurrections',
#        'The Mauritanian', 'The Medium', 'The Menu',
#        'The Ministry of Ungentlemanly Warfare', 'The Monkey King: Reborn',
#        'The Moon Thieves', 'The New Mutants', 'The New Toy',
#        'The Night House', 'The Night Owl',
#        'The Nightmare Before Christmas 30th Anniversary Re0Release',
#        'The Northman', 'The Nun II', 'The Peasants',
#        'The Personal History of David Copperfield', 'The Photograph',
#        'The Pioneer', 'The Pirates: The Last Royal Treasure', 'The Plot',
#        'The Point Men', "The Pope's Exorcist", 'The Post 2020 Re0release',
#        'The Promised Neverland', 'The ProtÃ©gÃ©',
#        'The Quintessential Quintuplets Movie', 'The Real Exorcist',
#        'The Rescue', 'The Rhythm Section', 'The Roundup',
#        'The Roundup: No Way Out', 'The Roundup: Punishment',
#        'The Royal Bride', 'The Sacrifice', 'The Second Act',
#        'The Secret Garden', 'The Shift', 'The Silent Service', 'The Soul',
#        'The SpongeBob Movie: Sponge on the Run',
#        'The Strangers: Chapter 1', 'The Stronghold', 'The Suicide Squad',
#        'The Super Mario Bros. Movie', 'The Tales for Old and Young',
#        'The Taste of Things', "The Tatta's",
#        "The Three Musketeers 0 Part I: D'Artagnan",
#        'The Three Musketeers 0 Part II: Milady', 'The Tomorrow War',
#        'The Turning', 'The Unbearable Weight of Massive Talent',
#        'The Unholy', 'The Untold Tale of the Three Kingdoms', 'The Vault',
#        'The Voice of Sin', 'The Wandering Earth II',
#        'The War with Grandpa', 'The Watchers', 'The Way Back',
#        'The Whale', 'The Wish of the Fairy Fish',
#        'The Witch: Part 2 0 The Other One', 'The Witches',
#        'The Wolf and the Lion', 'The Wolf of Wall Street 2022 Re0release',
#        'The Woman King', 'The Worst Person in the World',
#        'The Yin0Yang Master: Dream of Eternity', 'The Yinyang Master',
#        'The Zone of Interest', 'Thelma', "There's Still Tomorrow",
#        'Thor: Love and Thunder', 'Those Who Wish Me Dead',
#        'Threads 0 Our Tapestry of Love',
#        'Three Thousand Years of Longing',
#        'Three heroes and the Navel of the Earth', 'Ticket to Paradise',
#        'Tiger 3', 'Till', 'Titanic 25 Year Anniversary', 'Tokyo MER',
#        'Tokyo Revengers',
#        'Tokyo Revengers 2: Bloody Halloween 0 Decisive Battle',
#        'Tokyo Revengers 2: Bloody Halloween 0 Destiny', 'Tolo Tolo',
#        'Tom & Jerry', 'Tonde Saitama: Biwako Yori Ai o Komete',
#        'Too Cool to Kill', 'Too Old for Fairy Tales 2',
#        'Top Gun: Maverick', 'Toy Story 2023 Re0release',
#        'Transformers: Rise of the Beasts', 'Trap',
#        'Tri bogatyrya. Ni dnya bez podviga', 'Triangle of Sadness',
#        'Troll Factory', 'Trolls Band Together', 'Trolls World Tour',
#        'Turning Red', 'Twiceborn', 'Twilight of the Warriors: Walled In',
#        'Twisters', 'Two by Two: Overboard!', 'TÃ¡r',
#        'Uma Musume: Pretty Derby - Beginning of a New Era',
#        'Un mondo a parte', 'Uncharted', 'Underwater', 'Unhinged',
#        'Unsung Hero', 'Upcoming', 'Upon the Magic Roads',
#        'Utapri Movie 2, Uta No Prince0Sama Maji Love Starish Tours Movie',
#        'Vacaciones de verano', 'Vaillante', 'Vakeel Saab', 'Valimai',
#        'Vanguard', 'Venom: Let There Be Carnage', 'Vikram',
#        'Vikram Vedha', 'Violent Night', 'Violet Evergarden: The Movie',
#        'Voditel-oligarkh', 'Warm Hug', 'Warriors of Future',
#        'Water Gate Bridge', 'We 12', 'We Made a Beautiful Bouquet',
#        'Weekend Rebels', 'West Side Story', 'What Did You Eat Yesterday?',
#        "What's Love Got to Do with It?", 'Where the Crawdads Sing',
#        'White Bird', 'Whitney Houston: I Wanna Dance with Somebody',
#        'Wicked Little Letters', 'Wish', 'Wish Dragon', 'Women Talking',
#        'Wonder Woman 1984', 'Wonderland', 'Wonka',
#        'Wotakoi: Love Is Hard for Otaku', 'Wrath of Man', 'WunderschÃ¶n',
#        'X', 'Yolki 9', 'Yolo', 'Your Eyes Tell', 'Your Turn to Kill',
#        'Yowamushi Pedal: The Movie 2020 Re0release',
#        'ZÃ¡pisnÃ\xadk alkoholicky', 'Â¡A todo tren! Destino Asturias'],
#       dtype=object)

# %%
mcu = ['Black Panther 2020 Re0release', 'Black Panther: Wakanda Forever','Black Widow','Ant0Man and the Wasp: Quantumania',
'Deadpool & Wolverine','Doctor Strange in the Multiverse of Madness','Eternals','Guardians of the Galaxy Vol. 3','Shang0Chi and the Legend of the Ten Rings',
'Spider0Man: No Way Home','Spider0Man: No Way Home 2022 Re0release','The Marvels','Thor: Love and Thunder']

# %%
df[df['title'].isin(mcu)][['title', 'revenue_worldwide', 'revenue_domestic', 'domestic_pct',
       'revenue_foreign', 'foreign_pct', 'release_year', 'event_period']]
# Out:
#                                             title  revenue_worldwide  \
# 4057                Black Panther 2020 Re0release       2.804657e+07
# 4200                      Spider0Man: No Way Home       1.912234e+09
# 4208    Shang0Chi and the Legend of the Ten Rings       4.322433e+08
# 4210                                     Eternals       4.020649e+08
# 4212                                  Black Widow       3.797517e+08
# 4403  Doctor Strange in the Multiverse of Madness       9.557758e+08
# 4405               Black Panther: Wakanda Forever       8.592088e+08
# 4407                       Thor: Love and Thunder       7.609281e+08
# 4570      Spider0Man: No Way Home 2022 Re0release       9.613518e+06
# 4602               Guardians of the Galaxy Vol. 3       8.455558e+08
# 4609            Ant0Man and the Wasp: Quantumania       4.760712e+08
# 4628                                  The Marvels       2.061368e+08
# 4800                         Deadpool & Wolverine       1.043180e+09
#
#       revenue_domestic  domestic_pct  revenue_foreign  foreign_pct  \
# 4057          367000.0      1.302605     2.763519e+07    98.697395
# 4200       804793477.0     42.100000     1.107440e+09    57.900000
# 4208       224543292.0     51.900000     2.077000e+08    48.100000
# 4210       164870234.0     41.000000     2.371947e+08    59.000000
# 4212       183651655.0     48.400000     1.961000e+08    51.600000
# 4403       411331607.0     43.000000     5.444442e+08    57.000000
# 4405       453829060.0     52.800000     4.053798e+08    47.200000
# 4407       343256830.0     45.100000     4.176713e+08    54.900000
# 4570         9321593.0     97.000000     2.919250e+05     3.000000
# 4602       358995815.0     42.500000     4.865600e+08    57.500000
# 4609       214504909.0     45.100000     2.615663e+08    54.900000
# 4628        84500223.0     41.000000     1.216366e+08    59.000000
# 4800       506937007.0     48.600000     5.362432e+08    51.400000
#
#       release_year event_period
# 4057          2020     Covid-19
# 4200          2021     Covid-19
# 4208          2021     Covid-19
# 4210          2021     Covid-19
# 4212          2021     Covid-19
# 4403          2022     Recovery
# 4405          2022     Recovery
# 4407          2022     Recovery
# 4570          2022     Recovery
# 4602          2023     Recovery
# 4609          2023     Recovery
# 4628          2023     Recovery
# 4800          2024     Recovery

# %%
df.columns
# Out:
# Index(['title', 'revenue_worldwide', 'revenue_domestic', 'domestic_pct',
#        'revenue_foreign', 'foreign_pct', 'release_year', 'rank', 'title_key',
#        'event_period', 'is_franchise'],
#       dtype='object')

# %%
# MCU revenue trend
mcu = df[df['title'].str.contains('Avengers|Thor|Iron Man|Doctor Strange|Black Panther|Ant|Captain|Guardians|Marvel', case=False)]
mcu_trend = mcu.groupby('release_year')['revenue_worldwide'].mean().reset_index()

# Disney+ timeline points
disney_plus = {
    2019: 0,    # Launch
    2020: 50,   # early growth (approx millions subs)
    2021: 120,
    2022: 140,
    2023: 150,
    2024: 155
}

plt.figure(figsize=(10,6))

# MCU line
plt.plot(mcu_trend['release_year'], mcu_trend['revenue_worldwide']/1e9, color='teal', marker='o', label='Avg MCU Film Revenue ($B)')

# Disney+ overlay (secondary axis)
ax2 = plt.gca().twinx()
ax2.plot(list(disney_plus.keys()), list(disney_plus.values()), color='orange', linestyle='--', marker='x', label='Disney+ Subscribers (Millions)')

# Styling
plt.title("The Disney+ Effect: MCU Box Office vs Streaming Expansion (2012–2024)")
plt.xlabel("Year")
plt.grid(alpha=0.3)
plt.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.show()
